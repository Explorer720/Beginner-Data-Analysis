# %% [markdown]
# # Matplotlib_Day1B

# %%
import csv
from collections import Counter
import pandas as pd
import numpy as np
from matplotlib import pyplot  as plt

# %%
#inital data are hypothetical
#Data used from .csv are from Stack Overflow Developer Survey 2019

# %% [markdown]
# ### Bar Graph

# %%
plt.style.use('fivethirtyeight')
ages_x = [10,11,12,13,14,15,]

x_indexes = np.arange(len(ages_x))
width = 0.25

iq_nep_y = [110,95,101,110,123,100]
plt.bar(x_indexes - width,iq_nep_y, width=width,color="orange",label="Nepal")

iq_ind_y = [120,105,121,100,113,130]
plt.bar(x_indexes,iq_ind_y, width=width,color="green",label="India")

iq_chi_y = [120,105,121,100,113,130]
plt.bar(x_indexes + width,iq_chi_y, width=width,color="red",label="China")

plt.legend()
plt.title("Childern IQ of Nepal,India and China")
plt.xlabel('Ages')
plt.ylabel('IQ Scores')
plt.show()

# %%
plt.style.use('fivethirtyeight')
ages_x = [10,11,12,13,14,15,]

x_indexes = np.arange(len(ages_x))
width = 0.15

iq_nep_y = [110,95,101,110,123,100]
plt.bar(x_indexes - width,iq_nep_y, width=width,color="orange",label="Nepal")

iq_ind_y = [120,105,121,100,113,130]
plt.bar(x_indexes,iq_ind_y, width=width,color="green",label="India")

iq_chi_y = [120,105,121,100,113,130]
plt.bar(x_indexes + width,iq_chi_y, width=width,color="red",label="China")

plt.legend()
plt.title("Childern IQ of Nepal,India and China")
plt.xlabel('Ages')
plt.ylabel('IQ Scores')
plt.show()

# %%
plt.style.use('fivethirtyeight')
ages_x = [10,11,12,13,14,15,]

x_indexes = np.arange(len(ages_x))
width = 0.15

iq_nep_y = [110,95,101,110,123,100]
plt.bar(x_indexes - width,iq_nep_y, width=width,color="orange",label="Nepal")

iq_ind_y = [120,105,121,100,113,130]
plt.bar(x_indexes,iq_ind_y, width=width,color="green",label="India")

iq_chi_y = [120,105,121,100,113,130]
plt.bar(x_indexes + width,iq_chi_y, width=width,color="red",label="China")

plt.legend()
plt.xticks(ticks=x_indexes, labels=ages_x)
plt.title("Childern IQ of Nepal,India and China")
plt.xlabel('Ages')
plt.ylabel('IQ Scores')
plt.savefig("graph1.png")
plt.show()

# %% [markdown]
# ### Reading External .csv file

# %%
# through csv module

with open('data/data_1b.csv') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    
    language_counter = Counter()
    
    for row in csv_reader:
        language_counter.update(row['LanguageWorkedWith'].split(';'))
        
print(language_counter.most_common())
# Out:
# [('JavaScript', 59219), ('HTML/CSS', 55466), ('SQL', 47544), ('Python', 37757), ('Java', 35917), ('Bash/Shell/PowerShell', 31991), ('C#', 27097), ('PHP', 23030), ('C++', 20524), ('TypeScript', 18523), ('C', 18017), ('Other(s):', 7920), ('Ruby', 7331), ('Go', 7201), ('Assembly', 5833), ('Swift', 5744), ('Kotlin', 5620), ('R', 5048), ('VBA', 4781), ('Objective-C', 4191), ('Scala', 3309), ('Rust', 2794), ('Dart', 1683), ('Elixir', 1260), ('Clojure', 1254), ('WebAssembly', 1015), ('F#', 973), ('Erlang', 777)]

# %%
languages = []
popularity = []

# %%
for item in language_counter.most_common():
    languages.append(item[0])
    popularity.append(item[1])

# %%
print(languages)
# Out:
# ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java', 'Bash/Shell/PowerShell', 'C#', 'PHP', 'C++', 'TypeScript', 'C', 'Other(s):', 'Ruby', 'Go', 'Assembly', 'Swift', 'Kotlin', 'R', 'VBA', 'Objective-C', 'Scala', 'Rust', 'Dart', 'Elixir', 'Clojure', 'WebAssembly', 'F#', 'Erlang']

# %%
print(popularity)
# Out:
# [59219, 55466, 47544, 37757, 35917, 31991, 27097, 23030, 20524, 18523, 18017, 7920, 7331, 7201, 5833, 5744, 5620, 5048, 4781, 4191, 3309, 2794, 1683, 1260, 1254, 1015, 973, 777]

# %%
plt.bar(languages,popularity)
plt.xlabel('Programming Languages')
plt.ylabel('People Who Use It')
plt.show()
plt.savefig('roughbar.png')

# %%
plt.barh(languages,popularity)
plt.title("Programming Language Users")
plt.ylabel('Programming Languages')
plt.xlabel('People Who Use It')
plt.show()
plt.savefig('horzbar.png')

# %%
language_counter = Counter()
languages=[]
popularity=[]
for item in language_counter.most_common(10):
    languages.append(item[0])
    popularity.append(item[1])

# %%
print(languages)
print(popularity)
# Out:
# []
# []

# %%
plt.barh(languages,popularity)
plt.title("Programming Language Users")
plt.ylabel('Programming Languages')
plt.xlabel('People Who Use It')
plt.show()
plt.savefig('horzbar.png')

# %%
#got little rough from csv module

# %%
#single one(proper)

# %%
from collections import Counter
import pandas as pd
import numpy as np
from matplotlib import pyplot  as plt


plt.style.use('fivethirtyeight')
with open('data/data_1b.csv') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    
    language_counter = Counter()
    
    for row in csv_reader:
        language_counter.update(row['LanguageWorkedWith'].split(';'))
        
languages = []
popularity = []



for item in language_counter.most_common(15):
    languages.append(item[0])
    popularity.append(item[1])

languages.reverse()
popularity.reverse()

plt.barh(languages,popularity)
plt.title("Programming Language Users")
plt.xlabel('People Who Use It')
plt.show()

# %%
#using pandas

# %%
from collections import Counter
import pandas as pd
import numpy as np
from matplotlib import pyplot  as plt
plt.style.use('fivethirtyeight')
data = pd.read_csv('data/data_1b.csv')
ids = data['Respondent'] 
lang_response = data['LanguageWorkedWith']
language_counter = Counter()
    
for response in lang_response:
        language_counter.update(response.split(';'))
        
languages = []
popularity = []



for item in language_counter.most_common(15):
    languages.append(item[0])
    popularity.append(item[1])

languages.reverse()
popularity.reverse()

plt.barh(languages,popularity)
plt.title("Programming Language Users")
plt.xlabel('People Who Use It')
plt.show()
